# %% [markdown]
# # Reading data from different file formats

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Ojas Gupta\Downloads\H2HBABBA2672_Dataset.csv")

# %%
df.head()
# Out:
#   business_code cust_number      name_customer        clear_date  \
# 0          U001   200704858         WAKE trust  11-06-2019 00:00
# 1          U001   200668077  IN-N- corporation  19-03-2019 00:00
# 2          U001   200781803        JRD systems  08-11-2019 00:00
# 3          U001   200794332         COST trust               NaN
# 4          U001   200782001   GORDO foundation               NaN
#
#    buisness_year      doc_id posting_date  document_create_date  \
# 0           2019  1929408887   01-06-2019              20190531
# 1           2019  1928870879   27-02-2019              20190227
# 2           2019  1930051546   25-10-2019              20191024
# 3           2020  1930808340   22-04-2020              20200421
# 4           2020  1930648113   18-03-2020              20200313
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190601     20190616              USD            RV
# ...
